# %% [markdown]
# # 🥇 Camada Gold — Análise Exploratória dos Dados Agregados
# Exploração da camada analítica: contagem de breweries por tipo e localização.

# %%
import pandas as pd
import os

GOLD_PATH = '../data/gold/breweries_aggregated.parquet'

df = pd.read_parquet(GOLD_PATH, engine='pyarrow')

print(f'Shape: {df.shape}')
print(f'Colunas: {df.columns.tolist()}')
print(f'\nTotal de breweries: {df["brewery_count"].sum()}')
print(f'Países únicos: {df["country"].nunique()}')
print(f'Estados únicos: {df["state"].nunique()}')
print(f'Tipos únicos: {df["brewery_type"].nunique()}')
# Out:
# Shape: (447, 4)
# Colunas: ['brewery_type', 'country', 'state', 'brewery_count']
#
# Total de breweries: 9110
# Países únicos: 19
# Estados únicos: 136
# Tipos únicos: 14

# %%
# Visualiza todos os dados
df
# Out:
#     brewery_type        country    state  brewery_count
# 0          micro      Australia      ACT              7
# 1          large      Australia      NSW              3
# 2          micro      Australia      NSW            141
# 3          micro      Australia       NT              3
# 4          large      Australia      QLD              2
# ..           ...            ...      ...            ...
# 442      brewpub  United States  Wyoming             16
# 443       closed  United States  Wyoming              6
# 444        micro  United States  Wyoming             24
# 445     regional  United States  Wyoming              1
# 446      taproom  United States  Wyoming              5
#
# [447 rows x 4 columns]

# %%
# Total de breweries por tipo
by_type = df.groupby('brewery_type')['brewery_count'].sum().sort_values(ascending=False)
print('=== Total de breweries por tipo ===')
print(by_type.to_string())
# Out:
# === Total de breweries por tipo ===
# brewery_type
# micro         4845
# brewpub       2574
# planning       646
# closed         348
# regional       222
# contract       183
# large          112
# proprietor      65
# taproom         45
# bar             37
# nano            22
# cidery           7
# beergarden       3
# location         1

# %%
# Total de breweries por país
by_country = df.groupby('country')['brewery_count'].sum().sort_values(ascending=False)
print('=== Total de breweries por país ===')
print(by_country.to_string())
# Out:
# === Total de breweries por país ===
# country
# United States    8034
# Australia         514
# Canada            119
# South Africa      104
# Ireland            70
# England            62
# South Korea        61
# Poland             34
# Singapore          33
# Austria            15
# Portugal           14
# Scotland           10
# Germany            10
# Sweden             10
# Japan              10
# Italy               4
# France              3
# Isle of Man         2
# Ukraine             1

# %%
# Top 15 estados com mais breweries
by_state = df.groupby('state')['brewery_count'].sum().sort_values(ascending=False).head(15)
print('=== Top 15 estados com mais breweries ===')
print(by_state.to_string())
# Out:
# === Top 15 estados com mais breweries ===
# state
# California        919
# Washington        498
# Colorado          449
# New York          419
# Michigan          375
# Texas             352
# Pennsylvania      345
# Florida           312
# North Carolina    311
# Ohio              303
# Oregon            295
# Illinois          257
# Virginia          255
# Wisconsin         225
# Minnesota         183

# %%
# Pivot: tipo x país
pivot = df.pivot_table(
    values='brewery_count',
    index='brewery_type',
    columns='country',
    aggfunc='sum',
    fill_value=0
)
print('=== Breweries por tipo x país ===')
pivot
# Out:
# === Breweries por tipo x país ===
# country       Australia  Austria  Canada  England  France  Germany  Ireland  \
# brewery_type
# bar                   0        2       0        0       0        5        0
# beergarden            0        0       0        0       0        3        0
# brewpub               0        1      44       10       0        0        9
# cidery                0        0       6        0       0        0        0
# closed                0        0      12        0       0        0        0
# contract              0        0       0        0       0        0        0
# large                22       10       0        1       0        2        3
# location              0        0       0        0       0        0        0
# micro               491        0      54       40       3        0       49
# nano                  0        2       0        0       0        0        0
# planning              0        0       0        0       0        0        0
# proprietor            0        0       0        0       0        0        0
# regional              1        0       3        0       0        0        9
# taproom               0        0       0       11       0        0        0
#
# country       Isle of Man  Italy  Japan  Poland  Portugal  Scotland  \
# brewery_type
# bar                     0      0      0       0         0         0
# beergarden              0      0      0       0         0         0
# brewpub                 0      0      6      11         7         0
# cidery                  0      0      0       0         0         0
# closed                  0      0      0       0         0         1
# contract                0      0      0       0         0         0
# large                   0      1      0       0         0         0
# location                0      0      0       0         0         0
# micro                   2      1      4      20         7         9
# nano                    0      1      0       0         0         0
# planning                0      0      0       0         0         0
# proprietor              0      0      0       0         0         0
# regional                0      1      0       3         0         0
# taproom                 0      0      0       0         0         0
#
# country       Singapore  South Africa  South Korea  Sweden  Ukraine  \
# brewery_type
# bar                  28             0            0       0        0
# beergarden            0             0            0       0        0
# brewpub               4            44           56       0        0
# cidery                0             1            0       0        0
# closed                0             0            0       0        0
# contract              0             0            0       0        0
# large                 1             0            0       0        0
# location              0             0            0       0        0
# micro                 0            59            5      10        1
# nano                  0             0            0       0        0
# planning              0             0            0       0        0
# proprietor            0             0            0       0        0
# regional              0             0            0       0        0
# taproom               0             0            0       0        0
#
# country       United States
# brewery_type
# bar                       2
# beergarden                0
# brewpub                2382
# cidery                    0
# closed                  335
# contract                183
# large                    72
# location                  1
# micro                  4090
# nano                     19
# planning                646
# proprietor               65
# regional                205
# taproom                  34

# %%
# Verificação de qualidade: checar nulos e brewery_count = 0
print('=== Data Quality Check ===')
print(f'Valores nulos: {df.isnull().sum().sum()}')
print(f'Grupos com brewery_count = 0: {(df["brewery_count"] == 0).sum()}')
print(f'brewery_count mínimo: {df["brewery_count"].min()}')
print(f'brewery_count máximo: {df["brewery_count"].max()}')
print(f'brewery_count médio: {df["brewery_count"].mean():.2f}')
# Out:
# === Data Quality Check ===
# Valores nulos: 0
# Grupos com brewery_count = 0: 0
# brewery_count mínimo: 1
# brewery_count máximo: 466
# brewery_count médio: 20.38
