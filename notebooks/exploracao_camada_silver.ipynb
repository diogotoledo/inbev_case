# %% [markdown]
# # 🥈 Camada Silver — Análise Exploratória dos Dados Transformados
# Exploração dos dados transformados em Parquet, particionados por country/state.

# %%
import pandas as pd
import os
from glob import glob

SILVER_PATH = '../data/silver'

# Lista as partições criadas
partitions = sorted(glob(os.path.join(SILVER_PATH, 'country=*')))
print(f'Total de países (partições): {len(partitions)}')
for p in partitions:
    country = os.path.basename(p).replace('country=', '')
    states = glob(os.path.join(p, 'state=*'))
    print(f'  {country}: {len(states)} estados/regiões')
# Out:
# Total de países (partições): 19
#   Australia: 8 estados/regiões
#   Austria: 5 estados/regiões
#   Canada: 1 estados/regiões
#   England: 2 estados/regiões
#   France: 1 estados/regiões
#   Germany: 1 estados/regiões
#   Ireland: 24 estados/regiões
#   Isle%20of%20Man: 1 estados/regiões
#   Italy: 1 estados/regiões
#   Japan: 1 estados/regiões
#   Poland: 1 estados/regiões
#   Portugal: 8 estados/regiões
#   Scotland: 4 estados/regiões
#   Singapore: 1 estados/regiões
#   South%20Africa: 8 estados/regiões
#   South%20Korea: 15 estados/regiões
#   Sweden: 2 estados/regiões
#   Ukraine: 1 estados/regiões
#   United%20States: 51 estados/regiões

# %%
# Carrega toda a silver layer
df = pd.read_parquet(SILVER_PATH, engine='pyarrow')

# Converte colunas categóricas (vindas do particionamento)
for col in ['country', 'state', 'brewery_type']:
    if col in df.columns:
        df[col] = df[col].astype(str)

print(f'Shape: {df.shape}')
print(f'Colunas: {df.columns.tolist()}')
# Out:
# Shape: (9110, 16)
# Colunas: ['id', 'name', 'brewery_type', 'address_1', 'address_2', 'address_3', 'city', 'state_province', 'postal_code', 'longitude', 'latitude', 'phone', 'website_url', 'street', 'country', 'state']

# %%
# Primeiros registros
df.head(10)
# Out:
#                                      id                        name  \
# 0  e9f93b6a-72c5-4e40-9511-705480434310        Ale Mary Brewing Co.
# 1  f8f12185-fa7e-4442-a54c-d95544033a91        Bentspoke Brewing Co
# 2  b3b6361d-6cc8-43a7-9d36-23537e4bbf33       BentSpoke Brewing Co.
# 3  f382ba2a-f5e0-445c-99d8-47331ab79b59          Capital Brewing Co
# 4  27d80318-53d1-4a6f-a7dd-b584474a6f43         Capital Brewing Co.
# 5  c5bc0fac-0c2a-4e2e-8732-b2396c2db3b6     Capital Brewing Company
# 6  6c4d6ae2-dc6d-4e00-95e0-7b89a2b07e4e          Cypher Brewing Co.
# 7  d30841d8-0152-469f-9a19-1b97a5f965a6  2 HALFS Brewing Distilling
# 8  86fc7186-e3a3-42f2-9316-e33c8afa2b8a             7th Day Brewery
# 9  645a43c4-74b2-47e5-a795-f2b0f678df52      Akasha Brewing Company
#
#   brewery_type             address_1   address_2 address_3        city  \
# 0        micro    8 Gladstone Street     Unit 26   unknown    Fyshwick
# 1        micro        38 Mort Street          48   unknown     Braddon
# 2        micro        38 Mort Street          48   unknown     Braddon
# 3        micro          1 Dairy Road  Building 3   unknown    Fyshwick
# 4        micro          1 Dairy Road  Building 3   unknown    Fyshwick
# 5        micro          1 Dairy Road  Building 3   unknown    Fyshwick
# 6        micro      35 Hinder Street      Unit 3   unknown   Gungahlin
# 7        micro       2 Stokes Avenue     unknown   unknown  Alexandria
# 8        micro        9 Powells Road     unit 14   unknown   Brookvale
# 9        micro  10-12 Spencer Street     unknown   unknown   Five Dock
#
#   state_province postal_code   longitude   latitude            phone  \
# 0            ACT        2609  149.173169 -35.323520  +61 411 627 321
# 1            ACT        2612  149.132016 -35.273057  +61 2 6257 5220
# 2            ACT        2612  149.132016 -35.273057  +61 2 6257 5220
# 3            ACT        2609  149.163455 -35.321667  +61 2 5104 0915
# 4            ACT        2609  149.163455 -35.321667  +61 2 5104 0915
# 5            ACT        2609  149.163455 -35.321667  +61 2 5104 0915
# 6            ACT        2912  149.137655 -35.186106  +61 423 244 404
# 7            NSW        2015  151.197900 -33.902839  +61 2 8068 0915
# 8            NSW        2100  151.272749 -33.766814  +61 2 9939 4930
# 9            NSW        2046  151.118226 -33.869775  +61 2 9715 7156
#
#                            website_url                street    country state
# 0            https://www.alemary.beer/    8 Gladstone Street  Australia   ACT
# 1  http://www.bentspokebrewing.com.au/        38 Mort Street  Australia   ACT
# 2  http://www.bentspokebrewing.com.au/        38 Mort Street  Australia   ACT
# 3        http://www.capitalbrewing.co/          1 Dairy Road  Australia   ACT
# 4        http://www.capitalbrewing.co/          1 Dairy Road  Australia   ACT
# 5        http://www.capitalbrewing.co/          1 Dairy Road  Australia   ACT
# 6     http://www.cypherbrewing.com.au/      35 Hinder Street  Australia   ACT
# 7               https://2halfs.com.au/       2 Stokes Avenue  Australia   NSW
# 8     http://www.7thdaybrewery.com.au/        9 Powells Road  Australia   NSW
# 9     http://www.akashabrewing.com.au/  10-12 Spencer Street  Australia   NSW

# %%
# Tipos de dados após transformação
print('=== Tipos de dados ===')
print(df.dtypes)
print('\n=== Valores nulos após transformação ===')
nulls = df.isnull().sum()
print(nulls[nulls > 0] if nulls.any() else 'Nenhum valor nulo encontrado ✅')
# Out:
# === Tipos de dados ===
# id                 object
# name               object
# brewery_type       object
# address_1          object
# address_2          object
# address_3          object
# city               object
# state_province     object
# postal_code        object
# longitude         float64
# latitude          float64
# phone              object
# website_url        object
# street             object
# country            object
# state              object
# dtype: object
#
# === Valores nulos após transformação ===
# longitude    2279
# latitude     2279
# street        735
# dtype: int64

# %%
# Distribuição por país
print('=== Breweries por país ===')
print(df['country'].value_counts().to_string())
# Out:
# === Breweries por país ===
# United States    8034
# Australia         514
# Canada            119
# South Africa      104
# Ireland            70
# England            62
# South Korea        61
# Poland             34
# Singapore          33
# Austria            15
# Portugal           14
# Scotland           10
# Germany            10
# Sweden             10
# Japan              10
# Italy               4
# France              3
# Isle of Man         2
# Ukraine             1

# %%
# Distribuição por tipo de brewery
print('=== Breweries por tipo ===')
print(df['brewery_type'].value_counts().to_string())
# Out:
# === Breweries por tipo ===
# micro         4845
# brewpub       2574
# planning       646
# closed         348
# regional       222
# contract       183
# large          112
# proprietor      65
# taproom         45
# bar             37
# nano            22
# cidery           7
# beergarden       3
# location         1

# %%
# Top 10 estados com mais breweries
print('=== Top 10 estados com mais breweries ===')
print(df['state'].value_counts().head(10).to_string())
# Out:
# === Top 10 estados com mais breweries ===
# California        919
# Washington        498
# Colorado          449
# New York          419
# Michigan          375
# Texas             352
# Pennsylvania      345
# Florida           312
# North Carolina    311
# Ohio              303

# %%
# Estatísticas das coordenadas geográficas
print('=== Estatísticas de latitude/longitude ===')
print(f'\nRegistros com coordenadas: {df["latitude"].notna().sum()}')
print(f'Registros sem coordenadas: {df["latitude"].isna().sum()}')
# Out:
# === Estatísticas de latitude/longitude ===
#
# Registros com coordenadas: 6831
# Registros sem coordenadas: 2279

# %%
# Particionamento: tamanho de cada arquivo parquet por país
print('=== Tamanho dos arquivos Parquet por país ===')
for p in sorted(glob(os.path.join(SILVER_PATH, 'country=*'))):
    country = os.path.basename(p).replace('country=', '')
    parquet_files = glob(os.path.join(p, '**/*.parquet'), recursive=True)
    total_kb = sum(os.path.getsize(f) for f in parquet_files) / 1024
    print(f'{country}: {total_kb:.1f} KB ({len(parquet_files)} arquivo(s))')
# Out:
# === Tamanho dos arquivos Parquet por país ===
# Australia: 145.9 KB (8 arquivo(s))
# Austria: 51.4 KB (5 arquivo(s))
# Canada: 26.7 KB (1 arquivo(s))
# England: 28.3 KB (2 arquivo(s))
# France: 10.2 KB (1 arquivo(s))
# Germany: 11.0 KB (1 arquivo(s))
# Ireland: 247.8 KB (24 arquivo(s))
# Isle%20of%20Man: 10.0 KB (1 arquivo(s))
# Italy: 10.3 KB (1 arquivo(s))
# Japan: 11.6 KB (1 arquivo(s))
# Poland: 13.8 KB (1 arquivo(s))
# Portugal: 80.8 KB (8 arquivo(s))
# Scotland: 40.8 KB (4 arquivo(s))
# Singapore: 14.1 KB (1 arquivo(s))
# South%20Africa: 95.4 KB (8 arquivo(s))
# South%20Korea: 161.0 KB (15 arquivo(s))
# Sweden: 20.8 KB (2 arquivo(s))
# Ukraine: 9.5 KB (1 arquivo(s))
# United%20States: 1575.4 KB (51 arquivo(s))
