# %% [markdown]
# # 🟫 Camada Bronze — Análise Exploratória dos dados brutos
# Exploração dos dados brutos ingeridos da Open Brewery DB API.

# %%
import json
import os
import pandas as pd
from glob import glob

# Ajuste o caminho conforme sua máquina
BRONZE_PATH = '../data/bronze'

files = sorted(glob(os.path.join(BRONZE_PATH, 'breweries_raw_*.json')))
print(f'Arquivos encontrados: {len(files)}')
for f in files:
    size_kb = os.path.getsize(f) / 1024
    print(f'  {os.path.basename(f)} — {size_kb:.1f} KB')
# Out:
# Arquivos encontrados: 1
#   breweries_raw_20260227_162139.json — 4725.9 KB

# %%
# Carrega o arquivo mais recente
latest = files[-1]
with open(latest, 'r', encoding='utf-8') as f:
    raw_data = json.load(f)

print(f'Total de registros: {len(raw_data)}')
print(f'\nExemplo de registro bruto:')
print(json.dumps(raw_data[0], indent=2))
# Out:
# Total de registros: 9251
#
# Exemplo de registro bruto:
# {
#   "id": "5128df48-79fc-4f0f-8b52-d06be54d0cec",
#   "name": "(405) Brewing Co",
#   "brewery_type": "micro",
#   "address_1": "1716 Topeka St",
#   "address_2": null,
#   "address_3": null,
#   "city": "Norman",
#   "state_province": "Oklahoma",
#   "postal_code": "73069-8224",
#   "country": "United States",
#   "longitude": -97.46818222,
#   "latitude": 35.25738891,
#   "phone": "4058160490",
#   "website_url": "http://www.405brewing.com",
#   "state": "Oklahoma",
#   "street": "1716 Topeka St"
# }

# %%
# Converte para DataFrame para facilitar a exploração
df = pd.DataFrame(raw_data)
print(f'Shape: {df.shape}')
print(f'\nColunas disponíveis:')
print(df.columns.tolist())
# Out:
# Shape: (9251, 16)
#
# Colunas disponíveis:
# ['id', 'name', 'brewery_type', 'address_1', 'address_2', 'address_3', 'city', 'state_province', 'postal_code', 'country', 'longitude', 'latitude', 'phone', 'website_url', 'state', 'street']

# %%
# Primeiros registros
df.head(10)
# Out:
#                                      id                             name  \
# 0  5128df48-79fc-4f0f-8b52-d06be54d0cec                 (405) Brewing Co
# 1  9c5a66c8-cc13-416f-a5d9-0a769c87d318                 (512) Brewing Co
# 2  34e8c68b-6146-453f-a4b9-1f6cd99a5ada          1 of Us Brewing Company
# 3  6d14b220-8926-4521-8d19-b98a2d6ec3db             10 Barrel Brewing Co
# 4  e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2             10 Barrel Brewing Co
# 5  e432899b-7f58-455f-9c7b-9a6e2130a1e0             10 Barrel Brewing Co
# 6  ef970757-fe42-416f-931d-722451f1f59c             10 Barrel Brewing Co
# 7  9f1852da-c312-42da-9a31-097bac81c4c0  10 Barrel Brewing Co - Bend Pub
# 8  ea4f30c0-bce6-416b-8904-fab4055a7362     10 Barrel Brewing Co - Boise
# 9  1988eb86-f0a2-4674-ba04-02454efa0d31    10 Barrel Brewing Co - Denver
#
#   brewery_type                    address_1 address_2 address_3  \
# 0        micro               1716 Topeka St      None      None
# 1        micro        407 Radam Ln Ste F200      None      None
# 2        micro          8100 Washington Ave      None      None
# 3        large                62970 18th St      None      None
# 4        large  1135 NW Galveston Ave Ste B      None      None
# 5        large          1411 NW Flanders St      None      None
# 6        large                    1501 E St      None      None
# 7        large             62950 NE 18th St      None      None
# 8        large             826 W Bannock St      None      None
# 9        large               2620 Walnut St      None      None
#
#              city state_province postal_code        country   longitude  \
# 0          Norman       Oklahoma  73069-8224  United States  -97.468182
# 1          Austin          Texas  78745-1197  United States         NaN
# 2  Mount Pleasant      Wisconsin  53406-3920  United States  -87.883364
# 3            Bend         Oregon  97701-9847  United States -121.281706
# 4            Bend         Oregon  97703-2465  United States -121.328802
# 5        Portland         Oregon  97209-2620  United States -122.685506
# 6       San Diego     California  92101-6618  United States -117.129593
# 7            Bend         Oregon       97701  United States -121.280954
# 8           Boise          Idaho  83702-5857  United States -116.202929
# 9          Denver       Colorado  80205-2231  United States -104.985366
#
#     latitude       phone                   website_url       state  \
# 0  35.257389  4058160490     http://www.405brewing.com    Oklahoma
# 1        NaN  5129211545     http://www.512brewing.com       Texas
# 2  42.720108  2624847553  https://www.1ofusbrewing.com   Wisconsin
# 3  44.086835  5415851007       http://www.10barrel.com      Oregon
# 4  44.057565  5415851007                          None      Oregon
# 5  45.525979  5032241700       http://www.10barrel.com      Oregon
# 6  32.714813  6195782311           http://10barrel.com  California
# 7  44.091211  5415851007                          None      Oregon
# 8  43.618516  2083445870       http://www.10barrel.com       Idaho
# 9  39.759251  7205738992                          None    Colorado
#
#                         street
# 0               1716 Topeka St
# 1        407 Radam Ln Ste F200
# 2          8100 Washington Ave
# 3                62970 18th St
# 4  1135 NW Galveston Ave Ste B
# 5          1411 NW Flanders St
# 6                    1501 E St
# 7             62950 NE 18th St
# 8             826 W Bannock St
# 9               2620 Walnut St

# %%
# Tipos de dados e valores nulos
print('=== Tipos de dados ===')
print(df.dtypes)
print('\n=== Valores nulos por coluna ===')
nulls = df.isnull().sum()
print(nulls[nulls > 0].sort_values(ascending=False))
# Out:
# === Tipos de dados ===
# id                 object
# name               object
# brewery_type       object
# address_1          object
# address_2          object
# address_3          object
# city               object
# state_province     object
# postal_code        object
# country            object
# longitude         float64
# latitude          float64
# phone              object
# website_url        object
# state              object
# street             object
# dtype: object
#
# === Valores nulos por coluna ===
# address_3      9212
# address_2      8974
# longitude      2290
# latitude       2290
# website_url    1222
# phone           946
# address_1       739
# street          739
# dtype: int64

# %%
# Distribuição por país
print('=== Breweries por país ===')
print(df['country'].value_counts())
# Out:
# === Breweries por país ===
# United States    8175
# Australia         514
# Canada            119
# South Africa      104
# Ireland            70
# England            62
# South Korea        61
# Poland             34
# Singapore          33
# Austria            15
# Portugal           14
# Japan              10
# Germany            10
# Sweden             10
# Scotland           10
# Italy               4
# France              3
# Isle of Man         2
# Ukraine             1
# Name: country, dtype: int64

# %%
# Distribuição por tipo
print('=== Breweries por tipo ===')
print(df['brewery_type'].value_counts())
# Out:
# === Breweries por tipo ===
# micro         4911
# brewpub       2620
# planning       649
# closed         361
# regional       230
# contract       184
# large          113
# proprietor      68
# taproom         45
# bar             37
# nano            22
# cidery           7
# beergarden       3
# location         1
# Name: brewery_type, dtype: int64

# %%
# Campos com dados faltantes em %
print('=== % de valores nulos por coluna ===')
missing_pct = (df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
print(missing_pct[missing_pct > 0].round(2).to_string())
# Out:
# === % de valores nulos por coluna ===
# address_3      99.58
# address_2      97.01
# longitude      24.75
# latitude       24.75
# website_url    13.21
# phone          10.23
# address_1       7.99
# street          7.99
